# %%
import pandas as pd
data = pd.read_csv('../data/preprocess_train.csv')

# %%
data
# Out:
#       sample_id   feature0       feature1  feature2   feature3    feature4  \
# 0             0  51.567250  288358.400000       NaN   1.855900  201.460169
# 1             1  63.804874  288358.400000  1.106802   1.050387  391.605375
# 2             2  49.138527  288358.400000  1.111649   0.767127  130.708067
# 3             3        NaN  288358.400000  1.109169        NaN  258.521076
# 4             4  76.520831  288358.400000  1.113410   5.795408  256.038997
# ...         ...        ...            ...       ...        ...         ...
# 6291       6291  70.406112  288358.400000  1.098904   0.134016  222.782078
# 6292       6292  72.795989  288358.400000       NaN   0.503558  408.101229
# 6293       6293  71.210154  515352.218703  2.101946  13.816881  -78.826173
# 6294       6294        NaN  288358.400000  1.106200   1.001885  218.883538
# 6295       6295  37.408452  288358.400000  1.101254        NaN   99.875245
#
# ...

# %%
data.iloc[:, 0]
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 6291    6291
# 6292    6292
# 6293    6293
# 6294    6294
# 6295    6295
# Name: sample_id, Length: 6296, dtype: int64

# %%
import numpy as np

# %%
arr = np.asarray(data.iloc[:, 0])

# %%
arr
# Out:
# array([   0,    1,    2, ..., 6293, 6294, 6295], dtype=int64)

# %%
data = pd.read_csv('../data/preprocess_train.csv')

# %%
data1000 = data.sample(n=1000, replace=False)

# %%
data1000
# Out:
#       sample_id   feature0  feature1  feature2  feature3    feature4  \
# 2847       2847  64.685536  288358.4  1.107554  0.577510  122.943731
# 606         606  29.431306  288358.4  2.107559  0.116808  217.697674
# 5754       5754        NaN  288358.4       NaN  0.426567  291.900308
# 1116       1116  51.134391  288358.4       NaN       NaN  275.144721
# 1044       1044  75.716630  288358.4  1.098828  1.567705  193.637512
# ...         ...        ...       ...       ...       ...         ...
# 1678       1678  81.822785  288358.4  1.101071  1.222203         NaN
# 1500       1500  63.327254  288358.4  1.104370  0.331997  276.370489
# 4003       4003  85.966590  288358.4  1.105322  0.668572  318.041954
# 1603       1603  21.780707  288358.4  1.104396       NaN  297.044429
# 3475       3475  81.518365  288358.4  1.098201  0.268730  194.189715
#
#        feature5   feature6      feature7       feature8  ...      feature98  \
# ...

# %%
data1000.to_csv('train_data_1000.csv', index=False)

# %%
data500 = data.sample(n=500, replace=False)
data500.to_csv('train_data_500.csv', index=False)

# %%
data200 = data.sample(n=200, replace=False)
data200.to_csv('train_data_200.csv', index=False)

# %%
data100 = data.sample(n=100, replace=False)
data100.to_csv('train_data_100.csv', index=False)

# %%
data1000 = data.sample(n=1000, replace=False)
data1000.to_csv('train_data_1000.csv', index=False)

# %%
data2000 = data.sample(n=2000, replace=False)
data2000.to_csv('train_data_2000.csv', index=False)

# %%
data5000 = data.sample(n=5000, replace=False)
data5000.to_csv('train_data_5000.csv', index=False)

# %%
test_data_200 = data.sample(n=200, replace=False)
test_data_200 = test_data_200.drop('label', axis=1)
test_data_200.to_csv('test_data_200.csv', index=False)

# %%
test_data_100 = data.sample(n=100, replace=False)
test_data_100 = test_data_100.drop('label', axis=1)
test_data_100.to_csv('test_data_100.csv', index=False)

# %%
test_data_500 = data.sample(n=500, replace=False)
test_data_500 = test_data_500.drop('label', axis=1)
test_data_500.to_csv('test_data_500.csv', index=False)

# %%
test_data_1000 = data.sample(n=1000, replace=False)
test_data_1000 = test_data_1000.drop('label', axis=1)
test_data_1000.to_csv('test_data_1000.csv', index=False)

# %%
test_data_50 = data.sample(n=50, replace=False).drop('label', axis=1)
test_data_50.to_csv('test_data_50.csv', index=False)

# %%
test_data_20 = data.sample(n=20, replace=False).drop('label', axis=1)
test_data_20.to_csv('test_data_20.csv', index=False)

# %%
test_data_10 = data.sample(n=10, replace=False).drop('label', axis=1)
test_data_10.to_csv('test_data_10.csv', index=False)

# %%
test_data_1 = data.sample(n=1, replace=False).drop('label', axis=1)
test_data_1.to_csv('test_data_1.csv', index=False)

# %%
test_data_5 = data.sample(n=5, replace=False).drop('label', axis=1)
test_data_5.to_csv('test_data_5.csv', index=False)

# %%
import pandas as pd
data = pd.read_csv('../data/preprocess_train.csv')

# %%
# Nan值解决
dict = {}
for column in data.columns.values:
    dict[column] = data[column].mean()
data = data.fillna(dict)

# %%
# 抽100条
